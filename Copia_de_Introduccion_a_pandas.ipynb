# %% [markdown]
# <a href="https://colab.research.google.com/github/Aksuya/InteligenciaArtificial/blob/main/Copia_de_Introduccion_a_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd


print(pd.__version__)

serieData= pd.Series(data=[100, 200, 300], index=['juan','pedro','lucas'])

print(serieData)
print('/////')
print(serieData['pedro'])

print(serieData.index)
print('pedro' in serieData)

myDictionary={'one':pd.Series([100,200,300], index=['juan','pedro','lucas']),
                                  'two':pd.Series ([11,22,33], index=['julio', 'pedro', 'lucas']) }

#SERIES AND DATAFRAME
#
df=pd.DataFrame(myDictionary)
print(df)
print('we are here.....')
print(df.index)
print(df.columns)

print('////////////')
print(df.loc['juan'])
# Out:
# 2.0.3
# juan     100
# pedro    200
# lucas    300
# dtype: int64
# /////
# 200
# Index(['juan', 'pedro', 'lucas'], dtype='object')
# True
#          one   two
# juan   100.0   NaN
# julio    NaN  11.0
# lucas  300.0  33.0
# pedro  200.0  22.0
# we are here.....
# Index(['juan', 'julio', 'lucas', 'pedro'], dtype='object')
# Index(['one', 'two'], dtype='object')
# ////////////
# one    100.0
# two      NaN
# Name: juan, dtype: float64

# %%
#18 de julio

df = pd.read_csv('/content/movies.csv')
df
# Out:
#        movieId                               title  \
# 0            1                    Toy Story (1995)
# 1            2                      Jumanji (1995)
# 2            3             Grumpier Old Men (1995)
# 3            4            Waiting to Exhale (1995)
# 4            5  Father of the Bride Part II (1995)
# ...        ...                                 ...
# 62418   209157                           We (2018)
# 62419   209159           Window of the Soul (2001)
# 62420   209163                    Bad Poems (2018)
# 62421   209169                 A Girl Thing (2001)
# 62422   209171      Women of Devil's Island (1962)
#
#                                             genres
# 0      Adventure|Animation|Children|Comedy|Fantasy
# 1                       Adventure|Children|Fantasy
# 2                                   Comedy|Romance
# 3                             Comedy|Drama|Romance
# 4                                           Comedy
# ...

# %%
df.head(3)
# Out:
#    movieId                    title  \
# 0        1         Toy Story (1995)
# 1        2           Jumanji (1995)
# 2        3  Grumpier Old Men (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance

# %%
df.tail(6)
# Out:
#        movieId                           title                  genres
# 62417   209155      Santosh Subramaniam (2008)   Action|Comedy|Romance
# 62418   209157                       We (2018)                   Drama
# 62419   209159       Window of the Soul (2001)             Documentary
# 62420   209163                Bad Poems (2018)            Comedy|Drama
# 62421   209169             A Girl Thing (2001)      (no genres listed)
# 62422   209171  Women of Devil's Island (1962)  Action|Adventure|Drama

# %%
del df['genres']

# %%
df
# Out:
#        movieId                               title
# 0            1                    Toy Story (1995)
# 1            2                      Jumanji (1995)
# 2            3             Grumpier Old Men (1995)
# 3            4            Waiting to Exhale (1995)
# 4            5  Father of the Bride Part II (1995)
# ...        ...                                 ...
# 62418   209157                           We (2018)
# 62419   209159           Window of the Soul (2001)
# 62420   209163                    Bad Poems (2018)
# 62421   209169                 A Girl Thing (2001)
# 62422   209171      Women of Devil's Island (1962)
#
# [62423 rows x 2 columns]

# %%
df.shape
# Out:
# (62423, 2)

# %%
df.columns
# Out:
# Index(['movieId', 'title'], dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=62423, step=1)

# %%
tmp=df.iloc[255]

# %%
tmp
# Out:
# movieId                                     258
# title      Kid in King Arthur's Court, A (1995)
# Name: 255, dtype: object

# %%
tmp['movieId']
# Out:
# 258

# %%
'movieId' in df.columns
# Out:
# True

# %%
df.iloc[[100,200,300]]
# Out:
#      movieId                 title
# 100      102      Mr. Wrong (1996)
# 200      202  Total Eclipse (1995)
# 300      304      Roommates (1995)

# %%
df.describe()
# Out:
#              movieId
# count   62423.000000
# mean   122220.387646
# std     63264.744844
# min         1.000000
# 25%     82146.500000
# 50%    138022.000000
# 75%    173222.000000
# max    209171.000000

# %%
summary = df.describe()
summary = summary.loc[['min', 'max', 'mean']]
summary
# Out:
#             movieId
# min        1.000000
# max   209171.000000
# mean  122220.387646

# %%
movies = pd.read_csv('/content/movies.csv')
ratings = pd.read_csv('/content/ratings.csv')
tags = pd.read_csv('/content/tags.csv')

# %%
movies.head(2)
# Out:
#    movieId             title                                       genres
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1        2    Jumanji (1995)                   Adventure|Children|Fantasy

# %%
ratings.head(2)
# Out:
#    userId  movieId  rating     timestamp
# 0       1      296     5.0  1.147880e+09
# 1       1      306     3.5  1.147869e+09

# %%
tags.head(2)
# Out:
#    userId  movieId      tag   timestamp
# 0       3      260  classic  1439472355
# 1       3      260   sci-fi  1439472256

# %%
del ratings['timestamp']
del tags['timestamp']

# %%
print(movies.shape)
print(ratings.shape)
print(tags.shape)
# Out:
# (62423, 3)
# (22403581, 3)
# (1093360, 3)

# %%
movies.isnull().any()
# Out:
# movieId    False
# title      False
# genres     False
# dtype: bool

# %%
ratings.isnull().any()
# Out:
# userId     False
# movieId    False
# rating     False
# dtype: bool

# %%
tags.isnull().any()
# Out:
# userId     False
# movieId    False
# tag         True
# dtype: bool

# %%
print(tags.shape)
aux1=tags.shape[0]
tags=tags.dropna()
aux2=tags.shape[0]
print(aux1)
print(tags.shape)
print(f'Muestras eliminadas en varibales tag', (aux1-aux2))
# Out:
# (1093360, 3)
# 1093360
# (1093344, 3)
# Muestras eliminadas en varibales tag 16

# %%
print(ratings.columns)
print(ratings['rating'].max())
print(f'Numero de muestras antes del filtro {ratings.shape}')
print(ratings['rating'].min())
calificacion_alta = ratings['rating']>=4
# Out:
# Index(['userId', 'movieId', 'rating'], dtype='object')
# 5.0
# Numero de muestras antes del filtro (22403581, 3)
# 0.5

# %%
ratings[calificacion_alta]
# Out:
#           userId  movieId  rating
# 0              1      296     5.0
# 2              1      307     5.0
# 3              1      665     5.0
# 5              1     1088     4.0
# 8              1     1237     5.0
# ...          ...      ...     ...
# 22403574  145661    47610     5.0
# 22403576  145661    48780     5.0
# 22403577  145661    48982     4.0
# 22403579  145661    49278     5.0
# 22403580  145661    50872     4.0
#
# [11151818 rows x 3 columns]

# %%
ratings_despues = ratings[calificacion_alta]
print("Numeros de muestra despues de filtro ", ratings_despues.shape)
# Out:
# Numeros de muestra despues de filtro  (11151818, 3)
